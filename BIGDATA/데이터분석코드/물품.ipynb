# %%
import pandas as pd

# %%
df = pd.read_csv('./Sales_data_RMF.csv')
# Out:
# /tmp/ipykernel_24966/354546881.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./Sales_data_RMF.csv')

# %%
df.head()
# Out:
#               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0  901011864201303  2021-01-05  2021-01-01  2020-12-31     35
# 1  901011864430366  2021-01-03  2021-01-01  2020-12-31      9
# 2   81231186197954  2021-01-05  2021-01-01  2020-12-31     22
# 3  812311863500220  2021-01-03  2021-01-01  2020-12-31      8
# 4  812311863220192  2021-01-03  2021-01-01  2020-12-31     23
#
#               고객번호   구매금액   결제금액 물품대분류                            상품명    포인트  \
# 0  201901010750089  74560  43825    팬티     하기스 매직핏팬티 5단계 남아 124매(팬티형)  30735
# 1  201901010750143  74560  43825    팬티     하기스 매직핏팬티 3단계 남아 184매(팬티형)  30735
# 2  201812310749820  53920  36769    팬티  하기스 네이처메이드 팬티 5단계 여아 80매(팬티형)  17151
# 3  201812310750007  52160  32408    팬티    하기스 보송보송팬티 4단계 공용 124매(팬티형)  19752
# 4  201812310749977  47360  30066    팬티   하기스 에어솔솔 팬티 5단계 남아용 80매(팬티형)  17294
#
#    배송준비시간    배송시간 물품중분류 물품소분류
# 0  1 days  4 days   기저귀   팬티형
# 1  1 days  2 days   기저귀   팬티형
# 2  1 days  4 days   기저귀   팬티형
# ...

# %%
test_df = df[df['상품명'].str.contains('그린핑거')]
test_df['상품명'].unique()
# Out:
# array(['그린핑거 촉촉한 자연보습 울트라크림 300g', '그린핑거 마이키즈 자두야에디션 샴푸 프레쉬 320ml',
#        '그린핑거 힘센보습 울트라 로션 260ml', '그린핑거 촉촉한 자연보습 로션 320ml',
#        '그린핑거 베이비 세라마이드 크림 150g', '그린핑거 베이비 세라마이드 로션 180g',
#        '그린핑거 힘센보습 울트라 샴푸 300ml', '그린핑거 시그니처 물티슈 캡형 64매 x 6팩',
#        '그린핑거 마이키즈 워시 대용량 500ml', '그린핑거 베이비 세라마이드 세트',
#        '그린핑거 힘센보습 울트라 워시 300ml', '그린핑거 마이키즈 자두야에디션 촉촉 립밤(사과향)',
#        '그린핑거 마이키즈 워시 500ml(대용량) + 샴푸 500ml(대용량)',
#        '그린핑거 촉촉한 자연보습 울트라크림 300g + 힘센보습 울트라 워시 300ml + 울트라 샴푸 300ml',
#        '그린핑거 마이키즈 로션 대용량 330ml', '그린핑거 마이키즈 훼이셜솝 160ml',
#        '그린핑거 마이키즈 얼굴로션 160ml', '그린핑거 마이키즈 자두야에디션 워시 프레쉬 320ml',
#        '그린핑거 촉촉한 자연보습 비누 80g x 2개입',
#        '그린핑거 베이비 세라마이드 워시 250ml + 세라마이드 크림 150g',
#        '그린핑거 마이키즈 크림 200ml X 2', '그린핑거 마이키즈 샴푸 대용량 500ml',
#        '그린핑거 촉촉한 자연보습 워시 320ml', '그린핑거 베이비 세라마이드 크림 150g X 2',
#        '그린핑거 촉촉한 자연보습 울트라크림 300g X 2', '그린핑거 베이비 세라마이드 워시 250ml',
#        '그린핑거 야외놀이 선크림 80ml', '그린핑거 마이키즈 자두야에디션 로션 프레쉬 320ml',
# ...

# %%
test_df[test_df['상품명']=='그린핑거 힘센보습 울트라 크리미오일 180ml (EA)']
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 181220  00506204207-30920693142865  2022-05-13  2022-05-08  2022-05-07      9
# 181533   00507222353-0659435588342  2022-05-12  2022-05-09  2022-05-08     11
# 184966  00521144711-90450152114060  2022-05-24  2022-05-22  2022-05-21     14
# 194516   00715085645-3616359588343  2022-07-19  2022-07-16  2022-07-15     14
# 195043    00719105629-513715212949  2022-07-22  2022-07-20  2022-07-19     18
# 199982    00806225722-705971819187  2022-08-13  2022-08-08  2022-08-07     30
#
#                    고객번호   구매금액   결제금액 물품대분류                             상품명  \
# 181220  201907260947880  22260  19860   SKC  그린핑거 힘센보습 울트라 크리미오일 180ml (EA)
# 181533  201904050861933  11130   8820   SKC  그린핑거 힘센보습 울트라 크리미오일 180ml (EA)
# 184966  201905270902394  15900  12090   SKC  그린핑거 힘센보습 울트라 크리미오일 180ml (EA)
# 194516  201904050861933  11130   9890   SKC  그린핑거 힘센보습 울트라 크리미오일 180ml (EA)
# ...

# %%
test_df = test_df[test_df['상품명'].str.contains('울트라')]
test_df['상품명'].unique()
# Out:
# array(['그린핑거 촉촉한 자연보습 울트라크림 300g', '그린핑거 힘센보습 울트라 로션 260ml',
#        '그린핑거 힘센보습 울트라 샴푸 300ml', '그린핑거 힘센보습 울트라 워시 300ml',
#        '그린핑거 촉촉한 자연보습 울트라크림 300g + 힘센보습 울트라 워시 300ml + 울트라 샴푸 300ml',
#        '그린핑거 촉촉한 자연보습 울트라크림 300g X 2', '그린핑거 힘센보습 울트라 크리미오일 180ml',
#        '그린핑거 힘센 보습 울트라크림 300g', '그린핑거 힘센 보습 울트라크림 300g X 2',
#        '그린핑거 힘센보습 울트라크림 300g', '그린핑거 힘센보습 울트라크림 300g X 2',
#        '그린핑거 힘센보습 울트라 워시 300ml (EA)', '그린핑거 힘센보습 울트라 로션 260ml (EA)',
#        '그린핑거 힘센보습 울트라크림 300g (EA)', '그린핑거 힘센보습 울트라 샴푸 300ml (EA)',
#        '그린핑거 힘센보습 울트라 크리미오일 180ml (EA)'], dtype=object)

# %%
test_df[test_df['상품명']=='그린핑거 촉촉한 자연보습 울트라크림 300g + 힘센보습 울트라 워시 300ml + 울트라 샴푸 300ml']
# Out:
#                      주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 965      9011419000999173  2021-01-17  2021-01-15  2021-01-14     10
# 1516     9011919164736659  2021-01-22  2021-01-19  2021-01-18     75
# 2090    90123193286311520  2021-01-26  2021-01-24  2021-01-23     31
# 2097    90124193422719556  2021-01-27  2021-01-24  2021-01-23     46
# 2425     9012519423873996  2021-01-30  2021-01-26  2021-01-25     33
# 3132    90130196127716631  2021-02-03  2021-01-30  2021-01-29     44
# 4509    90201198184814614  2021-02-03  2021-02-01  2021-01-31     38
# 5141    90206199810217987  2021-02-09  2021-02-07  2021-02-06     22
# 10451   90226208299722944  2021-02-28  2021-02-26  2021-02-25     37
# 11171    9022720906926883  2021-03-03  2021-02-28  2021-02-27     32
# 11172   90227208913618120  2021-03-02  2021-02-28  2021-02-27     74
# 12761   90306212612225196  2021-03-11  2021-03-07  2021-03-06     17
# 13079   90307212984613909  2021-03-10  2021-03-08  2021-03-07     59
# ...

# %%
test_df[test_df['상품명']=='그린핑거 힘센보습 울트라크림 300g']
# Out:
#                       주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 141122   00109328086575634  2022-01-12  2022-01-09  2022-01-08    148
# 141782   00111328798174105  2022-01-13  2022-01-11  2022-01-10      4
# 142430  001123291478163228  2022-01-16  2022-01-13  2022-01-12      4
# 142431  001133293757181355  2022-01-16  2022-01-13  2022-01-12     13
# 142432  001133292787181982  2022-01-18  2022-01-13  2022-01-12      2
# ...                    ...         ...         ...         ...    ...
# 176005   00413365892263522  2022-04-17  2022-04-15  2022-04-14     26
# 176006  004143660740143237  2022-04-17  2022-04-15  2022-04-14      8
# 176290   00415366377185580  2022-04-19  2022-04-16  2022-04-15      9
# 176599   00416366684334576  2022-04-21  2022-04-17  2022-04-16     16
# 178295   00422368529120045  2022-04-26  2022-04-23  2022-04-22     16
#
#                    고객번호   구매금액   결제금액 물품대분류                   상품명   포인트  \
# ...

# %%
11900+11900+16500
# Out:
# 40300
