# %%
import pandas as pd

sales = pd.read_csv('./New_Sales_data1.csv', encoding = 'cp949')
# Out:
# /tmp/ipykernel_27496/4044243805.py:3: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('./New_Sales_data1.csv', encoding = 'cp949')

# %%
sales = sales.drop('Unnamed: 0', axis = 1)
sales.head()
# Out:
#               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0  901011864201303  2021-01-05  2021-01-01  2020-12-31   35.0
# 1  901011864430366  2021-01-03  2021-01-01  2020-12-31    9.0
# 2   81231186197954  2021-01-05  2021-01-01  2020-12-31   22.0
# 3  812311863500220  2021-01-03  2021-01-01  2020-12-31    8.0
# 4  812311863220192  2021-01-03  2021-01-01  2020-12-31   23.0
#
#               고객번호   구매금액   결제금액 물품대분류                            상품명    포인트  \
# 0  201901010750089  74560  43825    팬티     하기스 매직핏팬티 5단계 남아 124매(팬티형)  30735
# 1  201901010750143  74560  43825    팬티     하기스 매직핏팬티 3단계 남아 184매(팬티형)  30735
# 2  201812310749820  53920  36769    팬티  하기스 네이처메이드 팬티 5단계 여아 80매(팬티형)  17151
# 3  201812310750007  52160  32408    팬티    하기스 보송보송팬티 4단계 공용 124매(팬티형)  19752
# 4  201812310749977  47360  30066    팬티   하기스 에어솔솔 팬티 5단계 남아용 80매(팬티형)  17294
#
#    배송준비시간    배송시간
# 0  1 days  4 days
# 1  1 days  2 days
# 2  1 days  4 days
# 3  1 days  2 days
# 4  1 days  2 days

# %%
sales[sales['구매금액'] == 0]
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 178384  00423012956-37102306162007  2022-04-26  2022-04-24  2022-04-23    3.0
# 178385  00423024730-63142055162008  2022-04-26  2022-04-24  2022-04-23    3.0
# 181738  00509112542-71889175128751  2022-05-15  2022-05-10  2022-05-09   18.0
# 181906   00510120613-3562311924730  2022-05-13  2022-05-11  2022-05-10   13.0
# 181907   00510082045-0953867131019  2022-05-14  2022-05-11  2022-05-10   14.0
# ...                            ...         ...         ...         ...    ...
# 199957  00806194332-46933013172572  2022-08-10  2022-08-08  2022-08-07    5.0
# 199958  00806230001-95422214173608  2022-08-12  2022-08-08  2022-08-07    8.0
# 199959  00806155014-62372265179980  2022-08-10  2022-08-08  2022-08-07   10.0
# 199960  00806210424-48271954191116  2022-08-12  2022-08-08  2022-08-07    8.0
# 199979  00806170623-57766681182960  2022-08-10  2022-08-08  2022-08-07   10.0
#
# ...

# %%
product = pd.read_csv('./new_product_data2.csv', encoding = 'cp949')

# %%
product
# Out:
#      물품대분류 물품중분류  물품소분류                                상품명  물품판매량    제품단가
# 0      기저귀   기저귀    NaN      하기스 네이처메이드 5단계 여아 92매(밴드형) X2      3  104640
# 1      기저귀   기저귀    NaN      하기스 네이처메이드 5단계 여아 92매(밴드형) X3      2  156960
# 2      기저귀   기저귀    NaN                   하기스 네이처메이드 남아 세트    192   34880
# 3      기저귀   기저귀    NaN     하기스 네이처메이드 밤부 1단계 공용 186매(밴드형)    397   57911
# 4      기저귀   기저귀    NaN  하기스 네이처메이드 밤부 1단계 공용 186매(밴드형) X3      1  163440
# ...    ...   ...    ...                                ...    ...     ...
# 3043   기저귀   기저귀    NaN     하기스 네이처메이드 4단계 여아 108매(밴드형) X3     14  156960
# 3044   기저귀   기저귀    NaN         하기스 네이처메이드 5단계 남아 92매(밴드형)    156   73785
# 3045   기저귀   기저귀    NaN      하기스 네이처메이드 5단계 남아 92매(밴드형) X2      8  104640
# 3046   기저귀   기저귀    NaN      하기스 네이처메이드 5단계 남아 92매(밴드형) X3      4  156960
# 3047   기저귀   기저귀    NaN         하기스 네이처메이드 5단계 여아 92매(밴드형)    131   68296
#
# [3048 rows x 6 columns]

# %%
sales.loc[(sales['구매금액'] == 0) | (sales['결제금액'] == 0), ['구매금액']] = \
    sales.merge(product, on=['상품명', '물품대분류'], how='left')['제품단가']

# %%
sales.loc[(sales['구매금액'] == 0) | (sales['결제금액'] == 0), ['결제금액']] = \
    sales.merge(product, on=['상품명', '물품대분류'], how='left')['제품단가']

# %%
check_df2 = sales[sales['구매금액'] == 0]

# %%
check_df2.to_csv('./check2.csv')

# %%
sales[sales['상품명'] == '하기스 NEW 네이처메이드 썸머팬티 4단계 공용 82매(팬티형) X 2']
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 183391  00516134107-70831244127999  2022-05-22  2022-05-17  2022-05-16    8.0
# 183395  00515235902-00293864132708  2022-05-19  2022-05-17  2022-05-16   18.0
# 183402  00515195429-21769217166533  2022-05-19  2022-05-17  2022-05-16    8.0
# 183582   00516222242-5774670738004  2022-05-21  2022-05-18  2022-05-17   12.0
# 188543  00622111142-96473654154972  2022-06-25  2022-06-23  2022-06-22   16.0
# ...                            ...         ...         ...         ...    ...
# 199797  00805193713-94086968111694  2022-08-09  2022-08-07  2022-08-06   12.0
# 199799  00805192729-61899007171853  2022-08-12  2022-08-07  2022-08-06   10.0
# 199800  00805165802-72496874191582  2022-08-10  2022-08-07  2022-08-06    8.0
# 199955   00806151345-1101965299282  2022-08-10  2022-08-08  2022-08-07   14.0
# 199959  00806155014-62372265179980  2022-08-10  2022-08-08  2022-08-07   10.0
#
# ...

# %%
product[product['상품명'] == '하기스 NEW 네이처메이드 썸머팬티 4단계 공용 82매(팬티형) X 2']
# Out:
#      물품대분류 물품중분류  물품소분류                                      상품명  물품판매량  \
# 2274    팬티   기저귀    NaN  하기스 NEW 네이처메이드 썸머팬티 4단계 공용 82매(팬티형) X 2     75
#
#         제품단가
# 2274  119402

# %%
sales.to_csv('./new_sales_data3.csv', encoding = 'cp949', index = False)
