# %%
import pandas as pd

# %%
df_m = pd.read_csv('./Member_data_Allsum.csv')
df_s = pd.read_csv('./Sales_data_RMF.csv')
# Out:
# /tmp/ipykernel_29382/2153436019.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_m = pd.read_csv('./Member_data_Allsum.csv')
# /tmp/ipykernel_29382/2153436019.py:2: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_s = pd.read_csv('./Sales_data_RMF.csv')

# %%
df_s
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0                  901011864201303  2021-01-05  2021-01-01  2020-12-31     35
# 1                  901011864430366  2021-01-03  2021-01-01  2020-12-31      9
# 2                   81231186197954  2021-01-05  2021-01-01  2020-12-31     22
# 3                  812311863500220  2021-01-03  2021-01-01  2020-12-31      8
# 4                  812311863220192  2021-01-03  2021-01-01  2020-12-31     23
# ...                            ...         ...         ...         ...    ...
# 199994  00806233401-26770461124511  2022-08-11  2022-08-08  2022-08-07     13
# 199995   00806204436-0461904922687  2022-08-11  2022-08-08  2022-08-07    163
# 199996   00806204436-0461904922688  2022-08-12  2022-08-08  2022-08-07    163
# 199997  00806215930-05281256126202  2022-08-10  2022-08-08  2022-08-07      5
# 199998  00806233401-26770461124510  2022-08-10  2022-08-08  2022-08-07     13
#
# ...

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81360 entries, 0 to 81359
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   고객번호      81360 non-null  object
#  1   성별        81094 non-null  object
#  2   결혼유무      81094 non-null  object
#  3   거주지역      81094 non-null  object
#  4   연령        81094 non-null  float64
#  5   결제등록카드    81094 non-null  object
#  6   유입경로      81094 non-null  object
#  7   자녀여부      81094 non-null  object
#  8   구매일로부터기간  81360 non-null  int64
#  9   고객분류      81360 non-null  object
#  10  총구매횟수     67682 non-null  float64
#  11  총결제금액     67682 non-null  float64
#  12  총사용포인트    67682 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 8.1+ MB

# %%
df_m['자녀여부'].unique
# Out:
# <bound method Series.unique of 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 81355    NaN
# 81356    NaN
# 81357    NaN
# 81358    NaN
# 81359    NaN
# Name: 자녀여부, Length: 81360, dtype: object>

# %%
df_m['자녀여부'].isnull().sum()
df_m.dropna(subset=['자녀여부'],inplace=True)

# %%
df_nk = df_m[df_m['자녀여부'] == 'No']

# %%
df_nk
# Out:
#                   고객번호 성별 결혼유무 거주지역    연령  결제등록카드    유입경로 자녀여부  구매일로부터기간  \
# 3      201812310749774  여   미혼   경남  34.0    기업은행    지인추천   No       376
# 5      201812310749783  여   미혼   경기  26.0    광주은행    검색광고   No       365
# 13     201812310749818  여   미혼   충북  31.0  농협회원조합  네이버블로그   No       462
# 14     201812310749820  여   미혼   서울  31.0   신협중앙회   인스타그램   No       353
# 26     201812310749859  여   미혼   서울  30.0   새마을금고  네이버블로그   No       333
# ...                ... ..  ...  ...   ...     ...     ...  ...       ...
# 81075  201912291058097  여   미혼   인천  38.0    롯데카드    검색광고   No       223
# 81076  201912291058104  여   미혼   대전  33.0   농협중앙회   인스타그램   No       112
# 81078  201912291058112  여   미혼   강원  30.0   농협중앙회   인스타그램   No       223
# 81082  201912291058127  여   미혼   경기  31.0    국민은행   인스타그램   No        94
# 81083  201912291058135  여   미혼   인천  32.0    우리은행   네이버카페   No       122
#
#             고객분류  총구매횟수     총결제금액    총사용포인트
# 3           이탈고객    2.0  116532.0   35388.0
# ...

# %%
df_s.head()
# Out:
#               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0  901011864201303  2021-01-05  2021-01-01  2020-12-31     35
# 1  901011864430366  2021-01-03  2021-01-01  2020-12-31      9
# 2   81231186197954  2021-01-05  2021-01-01  2020-12-31     22
# 3  812311863500220  2021-01-03  2021-01-01  2020-12-31      8
# 4  812311863220192  2021-01-03  2021-01-01  2020-12-31     23
#
#               고객번호   구매금액   결제금액 물품대분류                            상품명    포인트  \
# 0  201901010750089  74560  43825    팬티     하기스 매직핏팬티 5단계 남아 124매(팬티형)  30735
# 1  201901010750143  74560  43825    팬티     하기스 매직핏팬티 3단계 남아 184매(팬티형)  30735
# 2  201812310749820  53920  36769    팬티  하기스 네이처메이드 팬티 5단계 여아 80매(팬티형)  17151
# 3  201812310750007  52160  32408    팬티    하기스 보송보송팬티 4단계 공용 124매(팬티형)  19752
# 4  201812310749977  47360  30066    팬티   하기스 에어솔솔 팬티 5단계 남아용 80매(팬티형)  17294
#
#    배송준비시간    배송시간 물품중분류 물품소분류
# 0  1 days  4 days   기저귀   팬티형
# 1  1 days  2 days   기저귀   팬티형
# 2  1 days  4 days   기저귀   팬티형
# ...

# %%
df_count = df_s.groupby('고객번호').size().reset_index(name='구매횟수')

# %%
df_count
# Out:
#                        고객번호  구매횟수
# 0           201812310749735     1
# 1           201812310749770     1
# 2           201812310749771     1
# 3           201812310749774     2
# 4           201812310749780     1
# ...                     ...   ...
# 97742  20200724113017315991     1
# 97743  20200729134409126553     1
# 97744  20200803075905757887     1
# 97745  20200805170229147688     1
# 97746  20200805223526494551     1
#
# [97747 rows x 2 columns]

# %%
df_LEFT_JOIN = pd.merge(df_s, df_nk, on='고객번호', how='left')

# %%
df = df_LEFT_JOIN[df_LEFT_JOIN['자녀여부'] =='No']

# %%
df['물품소분류'].value_counts()
# Out:
# 일반형        8227
# 수유용품       4635
# 팬티형        4485
# 화장지/물티슈    2866
# 생리대        1530
# 주방용품       1251
# 욕실용품        814
# 위생용품        782
# 스킨케어        771
# 세탁용품        461
# 기타          186
# 장난감         179
# 음식           60
# 의류           57
# 유아동침구        47
# 청소용품         26
# 건강기능식품       11
# 생활용품          4
# Name: 물품소분류, dtype: int64

# %%
df_LEFT_JOIN['물품소분류'].value_counts()
# Out:
# 일반형        57599
# 팬티형        41022
# 수유용품       30389
# 화장지/물티슈    23015
# 생리대        12367
# 주방용품        9307
# 위생용품        6285
# 욕실용품        6241
# 스킨케어        5959
# 세탁용품        3109
# 장난감         1431
# 기타          1215
# 음식          1033
# 의류           475
# 유아동침구        258
# 청소용품         188
# 건강기능식품        84
# 생활용품          22
# Name: 물품소분류, dtype: int64

# %%
df_LEFT_JOIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199998
# Data columns (total 27 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   주문번호      199999 non-null  object
#  1   배송완료일     199999 non-null  object
#  2   배송시작일     199999 non-null  object
#  3   구매일       199999 non-null  object
#  4   구매시월령     199999 non-null  int64
#  5   고객번호      199999 non-null  object
#  6   구매금액      199999 non-null  int64
#  7   결제금액      199999 non-null  int64
#  8   물품대분류     199999 non-null  object
#  9   상품명       199999 non-null  object
#  10  포인트       199999 non-null  int64
#  11  배송준비시간    199999 non-null  object
#  12  배송시간      199999 non-null  object
#  13  물품중분류     199999 non-null  object
#  14  물품소분류     199999 non-null  object
#  15  성별        26392 non-null   object
#  16  결혼유무      26392 non-null   object
#  17  거주지역      26392 non-null   object
#  18  연령        26392 non-null   float64
# ...

# %%
df_NK
# Out:
#       자녀여부  구매횟수
# 0       No   2.0
# 1       No   5.0
# 2       No   1.0
# 3       No   5.0
# 4       No   1.0
# ...    ...   ...
# 15744   No   1.0
# 15745   No   1.0
# 15746   No   1.0
# 15747   No   1.0
# 15748   No   3.0
#
# [15749 rows x 2 columns]

# %%
df_NK.groupby('구매횟수')

# %%
df_NK
# Out:
#       자녀여부  구매횟수
# 0       No   2.0
# 1       No   5.0
# 2       No   1.0
# 3       No   5.0
# 4       No   1.0
# ...    ...   ...
# 15744   No   1.0
# 15745   No   1.0
# 15746   No   1.0
# 15747   No   1.0
# 15748   No   3.0
#
# [15749 rows x 2 columns]

# %%
df_NK.isnull().sum()
df_NK =df_NK.fillna(0)

# %%
purchase_count
# Out:
#       자녀여부
# 구매횟수
# 0.0   2870
# 1.0   7511
# 2.0   2478
# 3.0   1216
# 4.0    633
# 5.0    342
# 6.0    225
# 7.0    168
# 8.0     85
# 9.0     67
# 10.0    44
# 11.0    27
# 12.0    17
# 13.0    10
# 14.0    10
# 15.0     6
# 16.0     3
# 17.0     6
# 18.0     3
# 19.0     2
# 20.0     4
# 21.0     3
# 22.0     4
# 23.0     3
# 25.0     1
# 27.0     1
# 28.0     1
# 31.0     3
# 32.0     4
# 39.0     1
# 43.0     1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('font',family = 'NanumGothic')
matplotlib.rc('axes', unicode_minus = False)

data = {'0회': 2870, '1회': 7511, '2회': 2478, '3회': 1216, '4회': 633, '5회이상': 1041}
df = pd.DataFrame(data.items(), columns=['구매횟수', 'count'])

sns.barplot(x='구매횟수', y='count', data=df)

plt.show()

# %%
df = df.drop[df['물품중분류']=='기저귀']
