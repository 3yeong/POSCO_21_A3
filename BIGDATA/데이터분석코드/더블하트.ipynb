# %%
import pandas as pd

# %%
df = pd.read_csv('./member_RFM.csv')
df.head()
df[df['구매횟수'] > 1]
# Out:
#                   고객번호       최근구매일   날짜  구매횟수   총결제금액
# 2      201812310749820  2021-08-20  353     5  219351
# 3      201812310750007  2021-02-19  535     2   59171
# 6      201901010750075  2021-01-06  579     2   36006
# 10     201812310749946  2021-02-27  527     2    9523
# 13     201901010750264  2021-07-29  375     2   15295
# ...                ...         ...  ...   ...     ...
# 97180  201907180941780  2022-07-30    9     2   69966
# 97186  201910161009034  2022-08-04    4     2   55126
# 97208  201904020858881  2022-07-30    9     2   59807
# 97481  201912161045771  2022-08-05    3     2   39080
# 97527  201907090935473  2022-08-03    5     2   11682
#
# [34231 rows x 5 columns]

# %%
df_s = pd.read_csv('./Sales_data_RMF.csv')
df_s.head()
# Out:
# /tmp/ipykernel_29968/3262064402.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_s = pd.read_csv('./Sales_data_RMF.csv')
#               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0  901011864201303  2021-01-05  2021-01-01  2020-12-31     35
# 1  901011864430366  2021-01-03  2021-01-01  2020-12-31      9
# 2   81231186197954  2021-01-05  2021-01-01  2020-12-31     22
# 3  812311863500220  2021-01-03  2021-01-01  2020-12-31      8
# 4  812311863220192  2021-01-03  2021-01-01  2020-12-31     23
#
#               고객번호   구매금액   결제금액 물품대분류                            상품명    포인트  \
# 0  201901010750089  74560  43825    팬티     하기스 매직핏팬티 5단계 남아 124매(팬티형)  30735
# 1  201901010750143  74560  43825    팬티     하기스 매직핏팬티 3단계 남아 184매(팬티형)  30735
# 2  201812310749820  53920  36769    팬티  하기스 네이처메이드 팬티 5단계 여아 80매(팬티형)  17151
# 3  201812310750007  52160  32408    팬티    하기스 보송보송팬티 4단계 공용 124매(팬티형)  19752
# ...

# %%
df_one = df[df['구매횟수'] == 1]
df_one
# Out:
#                   고객번호       최근구매일   날짜  구매횟수  총결제금액
# 0      201901010750089  2020-12-31  585     1  43825
# 1      201901010750143  2020-12-31  585     1  43825
# 4      201812310749977  2020-12-31  585     1  30066
# 5      201812310749957  2020-12-31  585     1  19900
# 7      201901010750145  2020-12-31  585     1  19900
# ...                ...         ...  ...   ...    ...
# 97719  201911181032894  2022-08-07    1     1  30520
# 97720  201912171047083  2022-08-07    1     1  18400
# 97721  201901280778029  2022-08-07    1     1  15540
# 97722  201910221016307  2022-08-07    1     1  10650
# 97723  201901280776735  2022-08-07    1     1  11080
#
# [63493 rows x 5 columns]

# %%
df_one1 = pd.merge(df_one, df_s, on='고객번호', how='left')
df_one1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72682 entries, 0 to 72681
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객번호    72682 non-null  object
#  1   최근구매일   72682 non-null  object
#  2   날짜      72682 non-null  int64
#  3   구매횟수    72682 non-null  int64
#  4   총결제금액   72682 non-null  int64
#  5   주문번호    31485 non-null  object
#  6   배송완료일   31485 non-null  object
#  7   배송시작일   31485 non-null  object
#  8   구매일     31485 non-null  object
#  9   구매시월령   31485 non-null  float64
#  10  구매금액    31485 non-null  float64
#  11  결제금액    31485 non-null  float64
#  12  물품대분류   31485 non-null  object
#  13  상품명     31485 non-null  object
#  14  포인트     31485 non-null  float64
#  15  배송준비시간  31485 non-null  object
#  16  배송시간    31485 non-null  object
#  17  물품중분류   31485 non-null  object
#  18  물품소분류   31485 non-null  object
# dtypes: float64(4), int64(3), object(12)
# memory usage: 11.1+ MB

# %%
df_one1 = df_one1.dropna()

df_one1[df_one1['물품대분류'] =='더블하트']
# Out:
#                   고객번호       최근구매일   날짜  구매횟수  총결제금액  \
# 54     201901020750769  2021-01-01  584     1   7642
# 431    201901150759963  2021-01-14  571     1  26990
# 433    201901050753340  2021-01-14  571     1  59650
# 434    201901050753340  2021-01-14  571     1  59650
# 779    201901100756789  2021-01-20  565     1  19600
# ...                ...         ...  ...   ...    ...
# 72646  201910201012661  2022-08-06    2     1  20420
# 72647  201910201012717  2022-08-06    2     1  23780
# 72649  201908220967082  2022-08-06    2     1   3697
# 72650  201904080863866  2022-08-06    2     1  17967
# 72673  201903170842279  2022-08-07    1     1   9690
#
#                              주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 54               0020533718551082  2022-02-09  2022-02-05  2022-02-04   11.0
# 431              0020433712189455  2022-02-07  2022-02-05  2022-02-04   11.0
# 433              0033035977303377  2022-04-03  2022-03-31  2022-03-30    0.0
# ...

# %%
df_one1.isnull().sum()
# Out:
# 고객번호      0
# 최근구매일     0
# 날짜        0
# 구매횟수      0
# 총결제금액     0
# 주문번호      0
# 배송완료일     0
# 배송시작일     0
# 구매일       0
# 구매시월령     0
# 구매금액      0
# 결제금액      0
# 물품대분류     0
# 상품명       0
# 포인트       0
# 배송준비시간    0
# 배송시간      0
# 물품중분류     0
# 물품소분류     0
# dtype: int64

# %%
df_one1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31485 entries, 53 to 72681
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객번호    31485 non-null  object
#  1   최근구매일   31485 non-null  object
#  2   날짜      31485 non-null  int64
#  3   구매횟수    31485 non-null  int64
#  4   총결제금액   31485 non-null  int64
#  5   주문번호    31485 non-null  object
#  6   배송완료일   31485 non-null  object
#  7   배송시작일   31485 non-null  object
#  8   구매일     31485 non-null  object
#  9   구매시월령   31485 non-null  float64
#  10  구매금액    31485 non-null  float64
#  11  결제금액    31485 non-null  float64
#  12  물품대분류   31485 non-null  object
#  13  상품명     31485 non-null  object
#  14  포인트     31485 non-null  float64
#  15  배송준비시간  31485 non-null  object
#  16  배송시간    31485 non-null  object
#  17  물품중분류   31485 non-null  object
#  18  물품소분류   31485 non-null  object
# dtypes: float64(4), int64(3), object(12)
# memory usage: 4.8+ MB

# %%
df_two = df[df['구매횟수'] > 1]
df_two
# Out:
#                   고객번호       최근구매일   날짜  구매횟수   총결제금액
# 2      201812310749820  2021-08-20  353     5  219351
# 3      201812310750007  2021-02-19  535     2   59171
# 6      201901010750075  2021-01-06  579     2   36006
# 10     201812310749946  2021-02-27  527     2    9523
# 13     201901010750264  2021-07-29  375     2   15295
# ...                ...         ...  ...   ...     ...
# 97180  201907180941780  2022-07-30    9     2   69966
# 97186  201910161009034  2022-08-04    4     2   55126
# 97208  201904020858881  2022-07-30    9     2   59807
# 97481  201912161045771  2022-08-05    3     2   39080
# 97527  201907090935473  2022-08-03    5     2   11682
#
# [34231 rows x 5 columns]

# %%
df_two1 = pd.merge(df_s, df_two, on='고객번호', how='outer')
df_two1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239814 entries, 0 to 239813
# Data columns (total 19 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   주문번호    228471 non-null  object
#  1   배송완료일   228471 non-null  object
#  2   배송시작일   228471 non-null  object
#  3   구매일     228471 non-null  object
#  4   구매시월령   228471 non-null  float64
#  5   고객번호    239814 non-null  object
#  6   구매금액    228471 non-null  float64
#  7   결제금액    228471 non-null  float64
#  8   물품대분류   228471 non-null  object
#  9   상품명     228471 non-null  object
#  10  포인트     228471 non-null  float64
#  11  배송준비시간  228471 non-null  object
#  12  배송시간    228471 non-null  object
#  13  물품중분류   228471 non-null  object
#  14  물품소분류   228471 non-null  object
#  15  최근구매일   95011 non-null   object
#  16  날짜      95011 non-null   float64
#  17  구매횟수    95011 non-null   float64
#  18  총결제금액   95011 non-null   float64
# dtypes: float64(7), object(12)
# memory usage: 36.6+ MB

# %%
df_two1
# Out:
#                    주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0       901011864201303  2021-01-05  2021-01-01  2020-12-31   35.0
# 1       901011864430366  2021-01-03  2021-01-01  2020-12-31    9.0
# 2        81231186197954  2021-01-05  2021-01-01  2020-12-31   22.0
# 3        90403223538555  2021-04-06  2021-04-03  2021-04-02   25.0
# 4        90501232847856  2021-05-03  2021-05-01  2021-04-30   26.0
# ...                 ...         ...         ...         ...    ...
# 239809              NaN         NaN         NaN         NaN    NaN
# 239810              NaN         NaN         NaN         NaN    NaN
# 239811              NaN         NaN         NaN         NaN    NaN
# 239812              NaN         NaN         NaN         NaN    NaN
# 239813              NaN         NaN         NaN         NaN    NaN
#
#                    고객번호     구매금액     결제금액 물품대분류  \
# 0       201901010750089  74560.0  43825.0    팬티
# 1       201901010750143  74560.0  43825.0    팬티
# ...

# %%
df_two2 = df_two1[df_two1['물품대분류'] == '더블하트']

# %%
df_two2['고객번호'].nunique()
# Out:
# 23829
