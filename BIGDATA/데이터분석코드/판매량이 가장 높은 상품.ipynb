# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rc('font',family = 'NanumGothic')
matplotlib.rc('axes', unicode_minus = False)
df = pd.read_csv('./Sales_data_RMF.csv')
# Out:
# /tmp/ipykernel_5498/2760111510.py:7: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./Sales_data_RMF.csv')

# %%
kitchen_df = df[df['물품소분류'] == '주방용품']
feeding_df = df[df['물품소분류'] == '수유용품']
underwear_df = df[df['물품중분류']=='기저귀']

# 구매일별 물품소분류별 주문건수 계산
kitchen_count = kitchen_df.groupby('구매일')['주문번호'].count()
feeding_count = feeding_df.groupby('구매일')['주문번호'].count()
underwear_count = underwear_df.groupby('구매일')['주문번호'].count()

print(max(kitchen_count))
print(kitchen)

plt.figure(figsize=(30,10))
# 그래프 그리기
plt.plot(kitchen_count.index, kitchen_count.values, label='주방용품')
# plt.plot(feeding_count.index, feeding_count.values, label='수유용품')
# plt.plot(underwear_count.index, underwear_count.values, label='기저귀')

# 그래프 제목, 축 제목, 범례 추가
plt.title('구매일별 판매량')
plt.xlabel('구매일')
plt.ylabel('판매량')
plt.legend()

# 그래프 출력
plt.show()
# Out:
# 292

# %%
kitchen_count.sort_values()
# Out:
# 구매일
# 2022-05-13      1
# 2021-04-24      1
# 2022-06-11      1
# 2022-06-05      1
# 2021-10-08      1
#              ...
# 2021-02-24    144
# 2021-02-21    148
# 2021-10-23    189
# 2021-12-17    203
# 2021-12-16    292
# Name: 주문번호, Length: 574, dtype: int64

# %%
feeding_count.sort_values()
# Out:
# 구매일
# 2022-06-06       1
# 2022-06-07       1
# 2022-06-03       1
# 2022-06-14       1
# 2022-06-04       1
#               ...
# 2021-12-18     274
# 2022-01-08     284
# 2021-12-17     312
# 2021-01-30     964
# 2021-10-10    2003
# Name: 주문번호, Length: 577, dtype: int64

# %%
underwear_count.sort_values()
# Out:
# 구매일
# 2021-04-25      1
# 2022-07-14      1
# 2022-06-14      6
# 2022-06-10      8
# 2022-06-07      9
#              ...
# 2021-06-20    444
# 2021-07-28    492
# 2021-10-29    521
# 2021-08-26    554
# 2021-07-29    633
# Name: 주문번호, Length: 580, dtype: int64

# %%
kitchen_df['상품명'].value_counts()
# Out:
# 크리넥스 안심 클래식 키친타월 140매 X 12롤        1029
# 크리넥스 안심 클래식 키친타올 120매 X 4롤          816
# 스카트 항균 프레쉬블루 빨아쓰는 행주타월 45매 X 4롤     445
# 스카트 하루한장 양면수세미 설거지용 10매             436
# 크리넥스 안심 프리미엄 3겹 키친타월 140매 X 4롤      384
#                                    ...
# [실리만] 실리콘 병솔(트리) WSK337 - 이지민트        1
# [도담도담오가닉] 손타올2개+ 아기띠 침받이 2종 세트        1
# [실리만] 라이트 그립 뒤집개 WSK3325              1
# [실리만] 라이트 그립 국자(대) WSK3322            1
# [실리만] 실리콘 푸드 주머니 350ml WSK3193        1
# Name: 상품명, Length: 361, dtype: int64

# %%
kitchen_df[kitchen_df['구매일'] == '2021-12-16']['상품명'].value_counts()
# Out:
#                       주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 125875   91216316321317386  2021-12-19  2021-12-17  2021-12-16      5
# 125897   91216316321717754  2021-12-20  2021-12-17  2021-12-16      9
# 125932  912173175309138165  2021-12-19  2021-12-17  2021-12-16      7
# 125983  912173175168145614  2021-12-20  2021-12-17  2021-12-16      4
# 125997   91217317115495869  2021-12-19  2021-12-17  2021-12-16     17
# ...                    ...         ...         ...         ...    ...
# 126992  912173172849194495  2021-12-21  2021-12-17  2021-12-16     11
# 126993  912173172508194519  2021-12-19  2021-12-17  2021-12-16      1
# 126994  912173174991194591  2021-12-19  2021-12-17  2021-12-16      0
# 126995  912173174956194737  2021-12-20  2021-12-17  2021-12-16     51
# 126996  912173175689194774  2021-12-20  2021-12-17  2021-12-16      0
#
#                    고객번호   구매금액   결제금액 물품대분류                         상품명   포인트  \
# ...
