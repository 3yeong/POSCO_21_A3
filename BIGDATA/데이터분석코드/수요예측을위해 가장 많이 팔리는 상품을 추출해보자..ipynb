# %%
import pandas as pd

# %%
df = pd.read_csv('./Product_data.csv')

# %%
df.head()
# Out:
#   물품대분류                               상품명  물품판매량  제품단가
# 0    FC        (1+1) 좋은느낌 입는 오버나이트 대형 8개입     15     0
# 1    FC        (1+1) 좋은느낌 입는 오버나이트 중형 8개입     10     0
# 2    FC  (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)     27     0
# 3    FC  (1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)     12     0
# 4    FC   (핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입      4     0

# %%
df.sort_values('물품판매량', ascending=False).head(20)
# Out:
#      물품대분류                                       상품명  물품판매량   제품단가
# 2626   체험팩                                   맘큐 허그박스  12077   3000
# 768    기저귀               하기스 네이처메이드 2단계 여아 156매(밴드형)   3010  64679
# 766    기저귀               하기스 네이처메이드 2단계 남아 156매(밴드형)   2792  65175
# 2194  더블하트             더블하트 SofTouch 모유실감 젖꼭지 L (2입)   2782  22730
# 2201  더블하트             더블하트 SofTouch 모유실감 젖꼭지 M (2입)   2767  20583
# 774    기저귀               하기스 네이처메이드 3단계 여아 132매(밴드형)   2591  64072
# 771    기저귀               하기스 네이처메이드 3단계 남아 132매(밴드형)   2375  63401
# 2652   체험팩             하기스 맥스드라이 3단계 공용 20매(밴드형/체험팩)   2184   6040
# 2206  더블하트             더블하트 SofTouch 모유실감 젖꼭지 S (2입)   2102  17368
# 2198  더블하트            더블하트 SofTouch 모유실감 젖꼭지 LL (2입)   1852  22659
# 763    기저귀               하기스 네이처메이드 1단계 공용 186매(밴드형)   1774  61728
# 2596   체험팩       2020 하기스 매직 컴포트 3단계 공용 20매(밴드형/체험팩)   1340   4900
# 2655   체험팩          하기스 맥스드라이 팬티 4단계 남아 20매(팬티형/체험팩)   1211   7280
# ...

# %%
df[df['상품명'] == '맘큐 허그박스']
# Out:
#      물품대분류      상품명  물품판매량  제품단가
# 2626   체험팩  맘큐 허그박스  12077  3000

# %%
df2 = pd.read_csv('./소분류추가.csv', encoding = 'utf-8')

# %%
df2.sort_values('물품판매량', ascending=False).head(30)
# Out:
#      물품대분류 물품중분류  물품중분류.1                                       상품명  물품판매량  \
# 2836   체험팩   기저귀      일반형                                   맘큐 허그박스  12077
# 996    기저귀   기저귀      일반형               하기스 네이처메이드 2단계 여아 156매(밴드형)   3010
# 994    기저귀   기저귀      일반형               하기스 네이처메이드 2단계 남아 156매(밴드형)   2792
# 2408  더블하트  수유용품     수유용품             더블하트 SofTouch 모유실감 젖꼭지 L (2입)   2782
# 2415  더블하트  수유용품     수유용품             더블하트 SofTouch 모유실감 젖꼭지 M (2입)   2767
# 1002   기저귀   기저귀      일반형               하기스 네이처메이드 3단계 여아 132매(밴드형)   2591
# 999    기저귀   기저귀      일반형               하기스 네이처메이드 3단계 남아 132매(밴드형)   2375
# 2862   체험팩   기저귀      일반형             하기스 맥스드라이 3단계 공용 20매(밴드형/체험팩)   2184
# 2420  더블하트  수유용품     수유용품             더블하트 SofTouch 모유실감 젖꼭지 S (2입)   2102
# 2412  더블하트  수유용품     수유용품            더블하트 SofTouch 모유실감 젖꼭지 LL (2입)   1852
# 991    기저귀   기저귀      일반형               하기스 네이처메이드 1단계 공용 186매(밴드형)   1774
# ...

# %%
list(df2[df2['물품판매량'] >= 872]['상품명'])
# Out:
# ['하기스 네이처메이드 팬티 4단계 여아 96매(팬티형)',
#  '크리넥스 마이비데 46매 X 10팩',
#  '크리넥스 순수 3겹 소프트 27m-30롤',
#  '크리넥스 안심 클래식 키친타월 140매 X 12롤',
#  '크리넥스 여행용티슈 카카오프렌즈 70매 X 3개입',
#  '그린핑거 힘센보습 울트라 로션 260ml',
#  '[2019년형] 하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)',
#  '2020 하기스 매직 컴포트 3단계 공용 180매(밴드형)',
#  '하기스 네이처메이드 1단계 공용 186매(밴드형)',
#  '하기스 네이처메이드 2단계 남아 156매(밴드형)',
#  '하기스 네이처메이드 2단계 여아 156매(밴드형)',
#  '하기스 네이처메이드 3단계 남아 132매(밴드형)',
#  '하기스 네이처메이드 3단계 여아 132매(밴드형)',
#  '하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)',
#  '하기스 매직핏기저귀 2단계 공용 192매(밴드형)',
#  '하기스 맥스드라이 3단계 공용 132매(밴드형)',
#  '더블하트 SofTouch 모유실감 노꼭지 트윈팩 240ml(오렌지)',
#  '더블하트 SofTouch 모유실감 젖꼭지 L (2입)',
#  '더블하트 SofTouch 모유실감 젖꼭지 LL (2입)',
#  '더블하트 SofTouch 모유실감 젖꼭지 M (2입)',
#  '더블하트 SofTouch 모유실감 젖꼭지 S (2입)',
#  '더블하트 젖꼭지 브러쉬 와이드형+젖병 스펀지 브러쉬 일반형',
#  '릴리유 무민 리미티드 아기물티슈 캡형 80매X10팩',
#  '2020 하기스 매직 컴포트 3단계 공용 20매(밴드형/체험팩)',
#  '2020 하기스 매직팬티 컴포트 4단계 남아 20매(팬티형/체험팩)',
#  '2020 하기스 매직팬티 컴포트 4단계 여아 20매(팬티형/체험팩)',
#  '맘큐 허그박스',
#  '하기스 맥스드라이 3단계 공용 20매(밴드형/체험팩)',
# ...

# %%
x : 성별, 연령, 등.. 고객 정보 데이터를 다 때려넣어보면 머신러닝이 알아서 모델 만들어줌 ~
    머신러닝모델로 영향인자를 찾는거 자체가 말이 안됨
    지도학습에 분류를 쓰자
    이 모델을 활용해서 기존 고객들의 이탈을 방지할 수 있는 뭔가를 만들겠다 !
    성능같은거 미리 찾아두기
    x를 넣을 때 넣을 수 있는 애들으 ㄹ넣자.. 신규고객을 넣을 때 넣을 수 잇는거(구매횟수 이런건 안되니까)
