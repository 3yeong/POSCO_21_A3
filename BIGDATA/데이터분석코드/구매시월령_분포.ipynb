# %%
import pandas as pd

# %%
df_s = pd.read_csv('./Final_Sales_data.csv')
# Out:
# /tmp/ipykernel_24870/379381762.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_s = pd.read_csv('./Final_Sales_data.csv')

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   주문번호    199999 non-null  object
#  1   배송완료일   199999 non-null  object
#  2   배송시작일   199999 non-null  object
#  3   구매일     199999 non-null  object
#  4   구매시월령   199999 non-null  float64
#  5   고객번호    199999 non-null  object
#  6   구매금액    199999 non-null  int64
#  7   결제금액    199999 non-null  int64
#  8   물품대분류   199999 non-null  object
#  9   상품명     199999 non-null  object
#  10  포인트     199999 non-null  int64
#  11  배송준비시간  199999 non-null  object
#  12  배송시간    199999 non-null  object
#  13  물품중분류   199999 non-null  object
#  14  물품소분류   199999 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 22.9+ MB

# %%
df_2 = df_s.loc[(df_s['구매시월령'] >=0.0 ) & (df_s['구매시월령'] <= 2.0)]
df_4 = df_s.loc[(df_s['구매시월령'] >=2.1 ) & (df_s['구매시월령'] <= 4.0)]
df_6 = df_s.loc[(df_s['구매시월령'] >=4.1 ) & (df_s['구매시월령'] <= 6.0)]
df_8 = df_s.loc[(df_s['구매시월령'] >=6.1 ) & (df_s['구매시월령'] <= 8.0)]
df_10 = df_s.loc[(df_s['구매시월령'] >=8.1 ) & (df_s['구매시월령'] <= 10.0)]
df_12 = df_s.loc[(df_s['구매시월령'] >=10.1 ) & (df_s['구매시월령'] <= 12.0)]
df_24 = df_s.loc[(df_s['구매시월령'] >=12.1 ) & (df_s['구매시월령'] <= 24.0)]
df_36 = df_s.loc[(df_s['구매시월령'] >=24.1 ) & (df_s['구매시월령'] <= 36.0)]
df_38 = df_s.loc[(df_s['구매시월령'] >=36.1 )]

# %%
print(len(df_2))
print(len(df_4))
print(len(df_6))
print(len(df_8))
print(len(df_10))
print(len(df_12))
print(len(df_24))
print(len(df_36))
print(len(df_38))
# Out:
# 42958
# 24758
# 22312
# 18448
# 16438
# 12203
# 28437
# 10856
# 17949

# %%
df_ss = df_s[df_s['구매시월령']>=84.0]

# %%
df_ss.nunique()
# Out:
# 주문번호       4928
# 배송완료일       574
# 배송시작일       556
# 구매일         556
# 구매시월령       393
# 고객번호       2314
# 구매금액        555
# 결제금액       1715
# 물품대분류_x       9
# 상품명         971
# 포인트        1771
# 배송준비시간        1
# 배송시간          5
# 물품중분류        11
# 물품소분류        17
# 제품단가        897
# dtype: int64

# %%
df_s[df_s['구매시월령']>=84.0]
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 15                 901011864727440  2021-01-05  2021-01-01  2020-12-31   98.0
# 226               9010418738811836  2021-01-06  2021-01-04  2021-01-03  112.0
# 231               9010418738811837  2021-01-06  2021-01-04  2021-01-03  112.0
# 249               9010418750501802  2021-01-08  2021-01-05  2021-01-04   89.0
# 287               9010518764873150  2021-01-07  2021-01-05  2021-01-04   87.0
# ...                            ...         ...         ...         ...    ...
# 209931  00805231900-56481991170891  2022-08-09  2022-08-07  2022-08-06  276.0
# 209946   00806155436-6048224051561  2022-08-10  2022-08-08  2022-08-07  131.0
# 210025  00806164600-38823810194463  2022-08-10  2022-08-08  2022-08-07   86.0
# 210035   00806204436-0461904922687  2022-08-11  2022-08-08  2022-08-07  163.0
# 210036   00806204436-0461904922688  2022-08-12  2022-08-08  2022-08-07  163.0
#
# ...

# %%
import numpy as np

condition = df_s['구매시월령'] >= 312.0

subset = df_s[condition]
matching_rows = df_s[df_s['물품소분류'] == subset['물품소분류'].iloc[0]]

mode = int(matching_rows['구매시월령'].mode())
df_s.loc[condition, '구매시월령'] = mode

# %%
df_s[df_s['구매시월령']>=312]
# Out:
# Empty DataFrame
# Columns: [주문번호, 배송완료일, 배송시작일, 구매일, 구매시월령, 고객번호, 구매금액, 결제금액, 물품대분류, 상품명, 포인트, 배송준비시간, 배송시간, 물품중분류, 물품소분류]
# Index: []

# %%
df_s.rename(columns = {'물품대분류_x':'물품대분류'},inplace =True)
df_s.drop('제품단가',axis = 1, inplace =True)

# %%
df_s
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0                  901011864201303  2021-01-05  2021-01-01  2020-12-31   35.0
# 1                  901011864430366  2021-01-03  2021-01-01  2020-12-31    9.0
# 2                   81231186197954  2021-01-05  2021-01-01  2020-12-31   22.0
# 3                  812311863500220  2021-01-03  2021-01-01  2020-12-31    8.0
# 4                  812311863220192  2021-01-03  2021-01-01  2020-12-31   23.0
# ...                            ...         ...         ...         ...    ...
# 199994  00806233401-26770461124511  2022-08-11  2022-08-08  2022-08-07   13.0
# 199995   00806204436-0461904922687  2022-08-11  2022-08-08  2022-08-07  163.0
# 199996   00806204436-0461904922688  2022-08-12  2022-08-08  2022-08-07  163.0
# 199997  00806215930-05281256126202  2022-08-10  2022-08-08  2022-08-07    5.0
# 199998  00806233401-26770461124510  2022-08-10  2022-08-08  2022-08-07   13.0
#
# ...

# %%
df_s = pd.read_csv('./Sales_data_RMF.csv')
# Out:
# /tmp/ipykernel_24870/922523283.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_s = pd.read_csv('./Sales_data_RMF.csv')

# %%
df_s['구매시월령'] = df_s['구매시월령'].astype('int')

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   주문번호    199999 non-null  object
#  1   배송완료일   199999 non-null  object
#  2   배송시작일   199999 non-null  object
#  3   구매일     199999 non-null  object
#  4   구매시월령   199999 non-null  int64
#  5   고객번호    199999 non-null  object
#  6   구매금액    199999 non-null  int64
#  7   결제금액    199999 non-null  int64
#  8   물품대분류   199999 non-null  object
#  9   상품명     199999 non-null  object
#  10  포인트     199999 non-null  int64
#  11  배송준비시간  199999 non-null  object
#  12  배송시간    199999 non-null  object
#  13  물품중분류   199999 non-null  object
#  14  물품소분류   199999 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 22.9+ MB

# %%
df_s[df_s['구매시월령']==15]
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 184               9010318724011965  2021-01-07  2021-01-04  2021-01-03     15
# 185               9010418743272122  2021-01-06  2021-01-04  2021-01-03     15
# 237               9010518763403055  2021-01-07  2021-01-05  2021-01-04     15
# 495               9010918860645135  2021-01-11  2021-01-09  2021-01-08     15
# 574               9011018880455772  2021-01-14  2021-01-10  2021-01-09     15
# ...                            ...         ...         ...         ...    ...
# 199907   00805170958-3879758358415  2022-08-12  2022-08-07  2022-08-06     15
# 199910   00805170958-3879758358413  2022-08-10  2022-08-07  2022-08-06     15
# 199914  00806200903-66417349184924  2022-08-11  2022-08-08  2022-08-07     15
# 199926   00806184301-6576917249803  2022-08-12  2022-08-08  2022-08-07     15
# 199942   00806161902-4020069774285  2022-08-10  2022-08-08  2022-08-07     15
#
# ...

# %%
df_s.to_csv("Sales_data_RMF.csv", index = False,encoding = 'utf-8')

# %%
df_s = pd.read_csv('./Sales_data_RMF.csv')
# Out:
# /tmp/ipykernel_24870/922523283.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_s = pd.read_csv('./Sales_data_RMF.csv')

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   주문번호    199999 non-null  object
#  1   배송완료일   199999 non-null  object
#  2   배송시작일   199999 non-null  object
#  3   구매일     199999 non-null  object
#  4   구매시월령   199999 non-null  int64
#  5   고객번호    199999 non-null  object
#  6   구매금액    199999 non-null  int64
#  7   결제금액    199999 non-null  int64
#  8   물품대분류   199999 non-null  object
#  9   상품명     199999 non-null  object
#  10  포인트     199999 non-null  int64
#  11  배송준비시간  199999 non-null  object
#  12  배송시간    199999 non-null  object
#  13  물품중분류   199999 non-null  object
#  14  물품소분류   199999 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 22.9+ MB

# %%
df_s.isnull().sum()
# Out:
# 주문번호      0
# 배송완료일     0
# 배송시작일     0
# 구매일       0
# 구매시월령     0
# 고객번호      0
# 구매금액      0
# 결제금액      0
# 물품대분류     0
# 상품명       0
# 포인트       0
# 배송준비시간    0
# 배송시간      0
# 물품중분류     0
# 물품소분류     0
# dtype: int64

# %%
df_d = pd.read_csv('./Sales_data_RMF.csv')
# Out:
# /tmp/ipykernel_24870/707301579.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_d = pd.read_csv('./Sales_data_RMF.csv')

# %%
df_d
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0                  901011864201303  2021-01-05  2021-01-01  2020-12-31   35.0
# 1                  901011864430366  2021-01-03  2021-01-01  2020-12-31    9.0
# 2                   81231186197954  2021-01-05  2021-01-01  2020-12-31   22.0
# 3                  812311863500220  2021-01-03  2021-01-01  2020-12-31    8.0
# 4                  812311863220192  2021-01-03  2021-01-01  2020-12-31   23.0
# ...                            ...         ...         ...         ...    ...
# 199994  00806233401-26770461124511  2022-08-11  2022-08-08  2022-08-07   13.0
# 199995   00806204436-0461904922687  2022-08-11  2022-08-08  2022-08-07  163.0
# 199996   00806204436-0461904922688  2022-08-12  2022-08-08  2022-08-07  163.0
# 199997  00806215930-05281256126202  2022-08-10  2022-08-08  2022-08-07    5.0
# 199998  00806233401-26770461124510  2022-08-10  2022-08-08  2022-08-07   13.0
#
# ...

# %%
df_d['배송시간']
# Out:
# 2 days    109592
# 3 days     58115
# 4 days     33444
# 5 days      7373
# 6 days      1515
# Name: 배송시간, dtype: int64

# %%
df_m = pd.read_csv('./Member_data.csv')
# Out:
# /tmp/ipykernel_3859/941751604.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_m = pd.read_csv('./Member_data.csv')

# %%
df_m
# Out:
#                        고객번호   성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부
# 0           201812310749735    여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 1           201812310749770    여   기혼   제주  33.0   국민은행    검색광고  Yes
# 2           201812310749771    여   기혼   부산  32.0   하나은행  네이버블로그  Yes
# 3           201812310749774    여   미혼   경남  34.0   기업은행    지인추천   No
# 4           201812310749780    여   기혼   서울  32.0   신한은행    직접검색  Yes
# ...                     ...  ...  ...  ...   ...    ...     ...  ...
# 81355  20200724113017315991  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81356  20200729134409126553  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81357  20200803075905757887  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81358  20200805170229147688  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81359  20200805223526494551  NaN  NaN  NaN   NaN    NaN     NaN  NaN
#
# [81360 rows x 8 columns]

# %%
df_s
# Out:
#                               주문번호       배송완료일       배송시작일         구매일  구매시월령  \
# 0                  901011864201303  2021-01-05  2021-01-01  2020-12-31     35
# 1                  901011864430366  2021-01-03  2021-01-01  2020-12-31      9
# 2                   81231186197954  2021-01-05  2021-01-01  2020-12-31     22
# 3                  812311863500220  2021-01-03  2021-01-01  2020-12-31      8
# 4                  812311863220192  2021-01-03  2021-01-01  2020-12-31     23
# ...                            ...         ...         ...         ...    ...
# 199994  00806233401-26770461124511  2022-08-11  2022-08-08  2022-08-07     13
# 199995   00806204436-0461904922687  2022-08-11  2022-08-08  2022-08-07    163
# 199996   00806204436-0461904922688  2022-08-12  2022-08-08  2022-08-07    163
# 199997  00806215930-05281256126202  2022-08-10  2022-08-08  2022-08-07      5
# 199998  00806233401-26770461124510  2022-08-10  2022-08-08  2022-08-07     13
#
# ...

# %%
i
